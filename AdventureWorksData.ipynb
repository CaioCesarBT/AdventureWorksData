# %% [markdown]
# <a href="https://colab.research.google.com/github/CaioCesarBT/AdventureWorksData/blob/main/AdventureWorksData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando a biblioteca pandas
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/datasets/AdventureWorks.xlsx")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#visualizando as 5 primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
df.tail() #5 ultimas linhas
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 899 2008-03-22 2008-04-04      306        1226       19049  200803224CS555
# 900 2008-10-04 2008-10-15      306        1155       19057  200810044CS636
# 901 2008-12-11 2008-12-15      306        1155       19060  200812114CS676
# 902 2008-12-17 2008-12-21      306        1226       19060  200812174CS676
# 903 2008-12-21 2008-12-25      306        1155       19060  200812214CS676
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 899          330.99           999.0           6          419.58      5574.42
# 900          324.69           980.0           6         1176.00      4704.00
# 901          324.69           980.0           6         1176.00      4704.00
# 902          330.99           999.0           6         1198.80      4795.20
# 903          324.69           980.0           6         1176.00      4704.00
#
# ...

# %%
df.shape #total de linhas e colunas
# Out:
# (904, 16)

# %%
df.columns #Nome das colunas
# Out:
# Index(['Data Venda', 'Data Envio', 'ID Loja', 'ID Produto', 'ID Cliente',
#        'No. Venda', 'Custo Unitário', 'Preço Unitário', 'Quantidade',
#        'Valor Desconto', 'Valor Venda', 'Produto', 'Fabricante', 'Marca',
#        'Classe', 'Cor'],
#       dtype='object')

# %%
df.dtypes #o tipo de dado em cada coluna
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
df.describe() #retorna informaçoes estatisticas do conjunto de dados.
# Out:
#           ID Loja   ID Produto    ID Cliente  Custo Unitário  Preço Unitário  \
# count  904.000000   904.000000    904.000000      904.000000      904.000000
# mean   270.015487  1225.238938  19029.092920      272.006150      742.527965
# std     50.955280   706.698742     96.427655      129.765051      368.589889
# min    199.000000   366.000000  18815.000000        5.090000        9.990000
# 25%    199.000000   384.000000  18964.750000      324.690000      758.000000
# 50%    306.000000  1202.000000  19060.000000      330.660000      980.000000
# 75%    307.000000  1226.000000  19107.000000      348.580000      998.000000
# max    307.000000  2497.000000  19145.000000      348.580000      999.000000
#
#         Quantidade  Valor Desconto   Valor Venda
# count   904.000000      904.000000    904.000000
# mean     62.950221      689.123294   6620.139538
# std     148.945964      822.363117   4319.407257
# min       2.000000        0.000000    159.840000
# ...

# %%
#df.groupby () serve para agrupamento de dados

# %%
# .unique retorna os valores unicos, e .loc retorna a localizaçao, um sinal de = cria uma variavel, dois sinais de == é igualdade.

# %%
df['Custo Unitário'].mean()
# Out:
# 272.00615044247786

# %%
df["Custo Unitário"].sum()
# Out:
# 245893.55999999997

# %%
df.sample(20)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 727 2009-11-01 2009-11-11      306        2496       19076  200911015CS767
# 599 2008-01-02 2008-01-12      306        1155       19046  200801024CS525
# 663 2009-01-26 2009-02-08      199        1202       18909  200901264CS817
# 540 2009-12-21 2010-01-02      306         366       19078  200912213CS780
# 416 2008-12-15 2008-12-19      306        1178       19060  200812154CS676
# 729 2009-11-06 2009-11-19      307        2496       19139  200911065CS729
# 278 2008-08-04 2008-08-11      307        2497       19103  200808045CS628
# 347 2009-07-21 2009-08-03      199        1203       18969  200907214CS880
# 164 2008-06-23 2008-07-05      199        1202       18848  200806234CS620
# 144 2009-05-14 2009-05-25      306         366       19067  200905143CS746
# 142 2009-05-04 2009-05-17      199         366       18939  200905043CS848
# ...

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                   object
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
df['ID Loja']=df["ID Loja"].astype("object") #para mudar o tipo de dados usa-se .astype()

# %%
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# dtype: int64

# %%
# quando for substituir o objeto em memoria utiliza se inplace=True

# %%
df.sample(15)
# Out:
#     Data Venda Data Envio ID Loja  ID Produto  ID Cliente       No. Venda  \
# 333 2008-11-27 2008-12-10     307         384       19109  200811273CS655
# 722 2009-08-04 2009-08-13     199        2496       18975  200908045CS887
# 257 2008-07-23 2008-08-01     306        2496       19055  200807235CS608
# 901 2008-12-11 2008-12-15     306        1155       19060  200812114CS676
# 693 2008-11-20 2008-12-03     307        2496       19109  200811205CS655
# 890 2009-12-23 2009-12-30     199        1155       19033  200912234CS949
# 369 2008-01-21 2008-02-01     306        1203       19047  200801214CS529
# 714 2009-03-06 2009-03-11     199        2496       18921  200903065CS830
# 761 2008-11-18 2008-11-30     199        2497       18888  200811185CS795
# 66  2008-07-21 2008-07-29     306        1203       19054  200807214CS588
# 119 2009-06-18 2009-06-27     199        1155       18955  200906184CS866
# 849 2008-10-01 2008-10-12     306        1203       19057  200810014CS636
# ...

# %%
df["Valor Venda"].mean()
# Out:
# 6620.139538274336
